# %% [markdown]
# # **1 Hello World**

# %% [markdown]
# **Assignment 1.1**: WAP to print your name three times
#
# **Solution**

# %%
i = 0
while i < 3:
  print('Keshav Goyal')
  i = i + 1
# Out:
# Keshav Goyal
# Keshav Goyal
# Keshav Goyal

# %% [markdown]
# # **2 Add numbers and Concatenate strings**

# %% [markdown]
# **Assignment 2.1**: WAP to add three numbers and print the result.
#
# **Solution**

# %%
a = 12
b = 45
c = 78
print(a,'+',b,'+',c,'-->>',a+b+c)
# Out:
# 12 + 45 + 78 -->> 135

# %% [markdown]
# **Assignment 2.2**: WAP to concatenate three strings and print the result.
#
# **Solution**

# %%
a = "I"
b = "am"
c = "Alex"
print("Hello!",a,b,c)
# Out:
# Hello! I am Alex

# %% [markdown]
# # **4 Loop**

# %% [markdown]
# **Assignment 4.1:** WAP to print the table of 7, 9.
#
# **Solution**

# %%
for i in range(1,11):
  print('7 *',i,'=',7*i)
# Out:
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 7 * 10 = 70

# %%
i = 1
while i < 11:
  print('9 *',i,'=',9*i)
  i = i + 1
# Out:
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81
# 9 * 10 = 90

# %% [markdown]
# **Assignment 4.2:** WAP to print the table of n and n is given by user.
#
# **Solution**

# %%
k = input('Enter the number: ')
n = int(k)
for i in range(1,11):
  print(n,'*',i,'-->>',n*i)
# Out:
# 5 * 1 -->> 5
# 5 * 2 -->> 10
# 5 * 3 -->> 15
# 5 * 4 -->> 20
# 5 * 5 -->> 25
# 5 * 6 -->> 30
# 5 * 7 -->> 35
# 5 * 8 -->> 40
# 5 * 9 -->> 45
# 5 * 10 -->> 50

# %% [markdown]
# **Assignment 4.3:** WAP to add all the numbers from 1 to n and n is given by user.
#
# **Solution**

# %%
n = int(input('enter the no. : '))
n = n + 1
print('sum from 1 to', n-1, '-->>',sum(range(1,n)))
# Out:
# sum from 1 to 10 -->> 55

# %% [markdown]
# # **5 If-Else - Conditional Checking**

# %% [markdown]
# **Assignment 5.1:** WAP to find max among three numbers, input from user. [Try max() function]
#
# **Solution**

# %%
a = int(input('enter the first no. : '))
b = int(input('enter the second no. : '))
c = int(input('enter the third no. : '))
print('max no. among [',a,',',b,',',c,'] :',max(a,b,c))
# Out:
# max no. among [ 7 , 9 , 3 ] : 9

# %% [markdown]
# **Assignment 5.2:** WAP to add all numbers divisible by 7 and 9 from 1 to n, n is given by the user.
#
# **Solution**

# %%
n = int(input('enter the no. : '))
k = n//(9*7)
total = (9*7)*k*(k+1)//2
print('sum of all numbers divisible by 63 up to',n,'is -->>',total)
# Out:
# sum of all numbers divisible by 63 up to 100 is -->> 63

# %% [markdown]
# **Assignment 5.3:** WAP to add all prime numbers from 1 to n, n is given by the user.
#
# **Solution**

# %%
import math
n = int(input('enter the no. : '))
s = 0
for i in range(1,n+1):
  g = 1
  for j in range(2,int(math.sqrt(i))+1):
    if i % j == 0:
      g = 0
      break
  if g == 1 and i > 1:
    s = s + i

print('sum of all prime numbers from 1 to',n,'is -->>',s)
# Out:
# sum of all prime numbers from 1 to 9 is -->> 17

# %% [markdown]
# # **6 Functions**

# %% [markdown]
# **Assignment 6.1:** WAP using a function that adds all odd numbers from 1 to n, n is given by the user.
#
# **Solution**

# %%
def sum_of_odds(n):
  s = 0
  for i in range(1, n+1):
    if i % 2 != 0:
      s = s + i
  return s

n = int(input('enter the no.: '))
print('sum of all odd no. up to', n, 'is :', sum_of_odds(n))
# Out:
# sum of all odd no. up to 7 is : 16

# %% [markdown]
# **Assignment 6.2:** WAP using a function that adds all prime numbers from 1 to n, n given by the user.
#
# **Solution**

# %%
import math

def is_prime(num):
  if num < 2:
    return False
  for j in range(2, int(math.sqrt(num)) + 1):
    if num % j == 0:
      return False
  return True

def sum_of_primes(n):
  s = 0
  for i in range(1, n+1):
    if is_prime(i):
      s = s + i
  return s

n = int(input('enter the no. :'))
print('sum of all prime numbers from 1 to', n, 'is -->>', sum_of_primes(n))
# Out:
# sum of all prime numbers from 1 to 20 is -->> 77
